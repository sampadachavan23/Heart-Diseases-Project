# %% [markdown]
# # Heart Diseases Prediction

# %%
# Description About the Dataset :-

#heart disease
#Age: age of the patient [years]
#Sex: sex of the patient [M: Male, F: Female]
#ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
#RestingBP: resting blood pressure [mm Hg]
#Cholesterol: serum cholesterol [mm/dl]
#FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
#RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
#MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
#ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
#Oldpeak: oldpeak = ST [Numeric value measured in depression]
#ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
#HeartDisease: output class [1: heart disease, 0: Normal]

# %%
# Import Some Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data collection and Processing

# %%
# Loading the csv data to a Pandas Dataframe
data =pd.read_csv("C:/Users/hp/Downloads/heart.csv")

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
# Print first 10 rows of the dataset
data.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
# Print last 10 rows in the dataset
data.tail(10)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 908   63   M           ASY        140          187          0        LVH
# 909   63   F           ASY        124          197          0     Normal
# 910   41   M           ATA        120          157          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 908    144              Y      4.0       Up             1
# ...

# %%
# Number of rows and columns in  the dataset
data.shape
# Out:
# (918, 12)

# %% [markdown]
# # In this dataset 918 rows and 12 columns are there.

# %%
# Size of the dataset
data.size
# Out:
# 11016

# %%
# Getting some Information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
# checking for missing values
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # 0 shows there is no missing values in our dataset

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Statstical measures about the data
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
# Checking Unique Values

# %%
print(data.Sex.unique())
print(data.ChestPainType.unique())
print(data.RestingECG.unique())
print(data.ExerciseAngina.unique())
print(data.ST_Slope.unique())
# Out:
# ['M' 'F']
# ['ATA' 'NAP' 'ASY' 'TA']
# ['Normal' 'ST' 'LVH']
# ['N' 'Y']
# ['Up' 'Flat' 'Down']

# %%
# Replacing the Values

# %%
data["Sex"].replace(["M","F"],[0,1],inplace=True)
data["ChestPainType"].replace(["ATA","NAP","ASY","TA"],[0,1,2,3],inplace=True)
data["RestingECG"].replace(["Normal","ST","LVH"],[1,2,3],inplace=True)
data["ExerciseAngina"].replace(["N","Y"],[0,1],inplace=True)
data["ST_Slope"].replace(["Up","Flat","Down"],[1,2,3],inplace=True)

# %%
data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           1
# 1   49    1              1        160          180          0           1
# 2   37    0              0        130          283          0           2
# 3   48    1              2        138          214          0           1
# 4   54    0              1        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         1             0
# 1    156               0      1.0         2             1
# 2     98               0      0.0         1             0
# 3    108               1      1.5         2             1
# 4    122               0      0.0         1             0

# %% [markdown]
# # Data Visualization

# %%
# draw correlation matrix

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Box Plot

# %%
data.plot(kind="box",rot=90,figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
data=data[data.Cholesterol<400]

# %%
data.Cholesterol.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (905, 12)

# %%
# How many People have Heart Disease And Don't have Heart Disease

# %%
data["HeartDisease"].value_counts()
# Out:
# 1    500
# 0    405
# Name: HeartDisease, dtype: int64

# %%
sns.countplot(data["HeartDisease"])
plt.show()

# %%
# find count of Male and Female in this Dataset

# %%
data["Sex"].value_counts()  # male-0 , female - 1
# Out:
# 0    717
# 1    188
# Name: Sex, dtype: int64

# %%
data["Sex"].value_counts().plot(kind="bar",rot=30)
# Out:
# <AxesSubplot:>

# %%
# check Chest Pain Type 
  # ATA - ATypical Angina
  #NAP - Non Angina Pain
  #ASY - ASymptomatic
  #TA  - Typical Angina

# %%
sns.countplot(data["ChestPainType"])
plt.show()

# %% [markdown]
# # Splitting The Data

# %%
x=data.drop("HeartDisease",axis=1)
y=data["HeartDisease"]

# %%
print(x)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              0        140          289          0           1
# 1     49    1              1        160          180          0           1
# 2     37    0              0        130          283          0           2
# 3     48    1              2        138          214          0           1
# 4     54    0              1        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              3        110          264          0           1
# 914   68    0              2        144          193          1           1
# 915   57    0              2        130          131          0           1
# 916   57    1              0        130          236          0           3
# 917   38    0              1        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# ...

# %%
print(y)
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 905, dtype: int64

# %% [markdown]
# # Spliting the Data into training data & Test Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=12)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (905, 11) (633, 11) (272, 11)

# %% [markdown]
# # Model Training

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
model_L = LogisticRegression()
model_L.fit(x_train,y_train)
pred_L=model_L.predict(x_test)
confusion_matrix(y_test,pred_L)
print("Accuracy score on logistic Regression is :",accuracy_score(y_test,pred_L))
# Out:
# Accuracy score on logistic Regression is : 0.8529411764705882

# %% [markdown]
# # Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
model_D=DecisionTreeClassifier()
model_D.fit(x_train,y_train)
pred_D=model_D.predict(x_test)
confusion_matrix(y_test,pred_D)
print("Accuracy score on Decision Tree model is :",accuracy_score(y_test,pred_D))
# Out:
# Accuracy score on Decision Tree model is : 0.7904411764705882

# %%
from sklearn import tree
plt.figure(figsize=(25,20))
tree.plot_tree(model_D,filled=True,max_depth=3,fontsize=20)
plt.show()

# %% [markdown]
# # KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# K=10
model_K=KNeighborsClassifier(n_neighbors=10)
model_K.fit(x_train,y_train)
pred_K=model_K.predict(x_test)
confusion_matrix(y_test,pred_K)
print("Accuracy score on KNN model is :",accuracy_score(y_test,pred_K))
# Out:
# Accuracy score on KNN model is : 0.7242647058823529

# %%
# K=12
model_K=KNeighborsClassifier(n_neighbors=12)
model_K.fit(x_train,y_train)
pred_K=model_K.predict(x_test)
confusion_matrix(y_test,pred_K)
print("Accuracy score on KNN model is :",accuracy_score(y_test,pred_K))
# Out:
# Accuracy score on KNN model is : 0.7095588235294118

# %% [markdown]
# # Naive Bayes Algorithm

# %%
from sklearn.naive_bayes import GaussianNB
model_N=GaussianNB()
model_N.fit(x_train,y_train)
pred_N=model_N.predict(x_test)
confusion_matrix(y_test,pred_N)
print("Accuracy score on Naive Bayes model is :",accuracy_score(y_test,pred_N))
# Out:
# Accuracy score on Naive Bayes model is : 0.8382352941176471

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
model_SC=SVC()
model_SC.fit(x_train,y_train)
pred_SC=model_SC.predict(x_test)
confusion_matrix(y_test,pred_SC)
print("Accuracy score on Support Vector Machine model is :",accuracy_score(y_test,pred_SC))
# Out:
# Accuracy score on Support Vector Machine model is : 0.7316176470588235

# %% [markdown]
# # Random Forest Models

# %%
from sklearn.ensemble import RandomForestClassifier
model_R=RandomForestClassifier()
model_R.fit(x_train,y_train)
pred_R=model_R.predict(x_test)
print("Accuracy score on Random Forest model is :",accuracy_score(y_test,pred_R))
# Out:
# Accuracy score on Random Forest model is : 0.8676470588235294

# %%
# Logistic Regression=0.852
# Decision Tree= 0.79
# KNN = 0.72
# Naive Bayes = 0.83
# SVM= 0.73
# RFM=0.867
# According to this Random Forest Model shows High Accuracy

# %% [markdown]
# # predict by using input method

# %%
Age=input("Enter your age : ")
Sex=input("Enter your gender : ")# (0-male,1-female)
ChestPainType=input("Enter your ChestPainType : ")#[ATA:0 , NAP:1, ASY:2 ,TA:3 ]
Cholesterol=input("Enter your Cholesterol : ") # serum cholesterol(0-603) [mm/dl]
RestingBP=input("Enter your RestingBP : ")# (resting blood pressure(0-200) [mm Hg])
FastingBS=input("Enter your FastingBS : ")# (fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise])
RestingECG=input("Enter your RestingECG : ") # (resting electrocardiogram results( Normal:1 ,ST:2 , LVH:3))
MaxHR=input("Enter your MaxHR : ") # maximum heart rate achieved [Numeric value between 60 and 202]
ExerciseAngina=input("Enter your ExerciseAngina : ") # exercise-induced angina [N:0 , Y:1 ]
Oldpeak=input("Enter your Oldpeak : ") # ST [Numeric value measured in depression]
ST_Slope=input("Enter your the slope of the peak exercise ST segment : ") # [Up:1, Flat:2, Down:3]
output=model_R.predict([[Age,Sex,ChestPainType,RestingBP,Cholesterol,FastingBS,
       RestingECG,MaxHR,ExerciseAngina,Oldpeak,ST_Slope]])
if output == 0:
    print("Your Heart is Normal.")
else:
    print("You have Heart Disease, take care")
# Out:
# Enter your age : 30
# Enter your gender : 1
# Enter your ChestPainType : 2
# Enter your Cholesterol : 200
# Enter your RestingBP : 100
# Enter your FastingBS : 1
# Enter your RestingECG : 1
# Enter your MaxHR : 102
# Enter your ExerciseAngina : 0
# Enter your Oldpeak : 0.1
# Enter your the slope of the peak exercise ST segment : 2
# You have Heart Disease, take care
